# %% [markdown]
# Descriptive Statistics: STUDENTS PERFORMANCE

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # IMPORT DATA OF STUDENTS TO CHECK PERFORANCE

# %%
student_performance=pd.read_csv("D:\MY STUDY MATERIALS\SOME DATAS FOR ANALYSIS\StudentsPerformance.csv")

# %%
student_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# SHAPE AND SIZE OF DATA SET

# %%
student_performance.shape
# Out:
# (1000, 8)

# %%
student_performance.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# # Grouping by females

# %%
student_performance_grouped=student_performance.groupby('gender')
females=student_performance_grouped.get_group('female')
females
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Female math score

# %%
females_math=females['math score']
females_math
# Out:
# 0      72
# 1      69
# 2      90
# 5      71
# 6      88
#        ..
# 993    62
# 995    88
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 518, dtype: int64

# %% [markdown]
# # Descriptive statistics of Females

# %%
females_math.describe()
# Out:
# count    518.000000
# mean      63.633205
# std       15.491453
# min        0.000000
# 25%       54.000000
# 50%       65.000000
# 75%       74.000000
# max      100.000000
# Name: math score, dtype: float64

# %% [markdown]
# # Female :sum of math score

# %%
females_math.sum()
# Out:
# 32962

# %% [markdown]
# # Female average math score

# %%
females_math.mean()
# Out:
# 63.633204633204635

# %%
females_math.count()
# Out:
# 518

# %%
females_math.sum()
# Out:
# 32962

# %% [markdown]
# # female standard deviation of maths score

# %%
females_math.std()
# Out:
# 15.49145324233953

# %% [markdown]
# # female minimum maths score

# %%
females_math.min()
# Out:
# 0

# %% [markdown]
# # female variance of maths score

# %%
females_math.var()
# Out:
# 239.98512355959193

# %%
females_math.argmax()
# Out:
# 218

# %%
females_math.argmin()
# Out:
# 30

# %% [markdown]
# # Grouping by Males

# %%
student_performance_grouped=student_performance.groupby('gender')
males=student_performance_grouped.get_group('male')
males
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %% [markdown]
# # Male :math score

# %%
males_math=males['math score']
males_math
# Out:
# 3      47
# 4      76
# 7      40
# 8      64
# 10     58
#        ..
# 985    57
# 987    81
# 990    86
# 994    63
# 996    62
# Name: math score, Length: 482, dtype: int64

# %% [markdown]
# # Male :math score descriptive statistics

# %%
males_math.describe()
# Out:
# count    482.000000
# mean      68.728216
# std       14.356277
# min       27.000000
# 25%       59.000000
# 50%       69.000000
# 75%       79.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
males_math.sum()
# Out:
# 33127

# %% [markdown]
# # Male : average of math score

# %%
males_math.mean()
# Out:
# 68.72821576763485

# %% [markdown]
# # Male :median of math score

# %%
males_math.median()
# Out:
# 69.0

# %% [markdown]
# # Male : average of math score

# %%
males_math.mode()
# Out:
# 0    62
# dtype: int64

# %%
student_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Group by Masters

# %%
student_performance_grouped=student_performance.groupby('parental level of education')
parents_masters=student_performance_grouped.get_group('master\'s degree')
parents_masters
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 29   female        group D             master's degree      standard
# 32   female        group E             master's degree  free/reduced
# 79   female        group E             master's degree      standard
# 106  female        group D             master's degree      standard
# 128    male        group D             master's degree      standard
# 130    male        group D             master's degree      standard
# 162    male        group B             master's degree  free/reduced
# 164  female        group E             master's degree      standard
# 167  female        group B             master's degree  free/reduced
# ...

# %% [markdown]
# # Total math score of females and males

# %%
masters_female=np.sum(parents_masters.where(parents_masters['gender']=='male')['math score'])
masters_female
# Out:
# 1721.0

# %%
masters_male=np.sum(parents_masters.where(parents_masters['gender']=='female')['math score'])
masters_male
# Out:
# 2394.0

# %%
lunch_masters=list(parents_masters.loc[:,"lunch"].unique())
lunch_masters.sort()
print(lunch_masters,end="")
# Out:
# ['free/reduced', 'standard']
