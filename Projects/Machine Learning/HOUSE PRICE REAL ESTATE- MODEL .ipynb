# %% [markdown]
# # HOUSE PRICE MODEL

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
# %matplotlib inline

# %%
d=pd.read_csv('houseprices.csv')

# %%
d
# Out:
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II   2.0
# 1                Plot  Area  Ready To Move          Chikka Tirupathi   4.0
# 2            Built-up  Area  Ready To Move               Uttarahalli   3.0
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli   3.0
# 4      Super built-up  Area  Ready To Move                  Kothanur   2.0
# ...                     ...            ...                       ...   ...
# 13315        Built-up  Area  Ready To Move                Whitefield   5.0
# 13316  Super built-up  Area  Ready To Move             Richards Town   4.0
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar   2.0
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar   4.0
# 13319  Super built-up  Area  Ready To Move              Doddathoguru   1.0
#
#        society  total_sqft  bath  balcony   price  total price
# ...

# %%
df=d
df
# Out:
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II   2.0
# 1                Plot  Area  Ready To Move          Chikka Tirupathi   4.0
# 2            Built-up  Area  Ready To Move               Uttarahalli   3.0
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli   3.0
# 4      Super built-up  Area  Ready To Move                  Kothanur   2.0
# ...                     ...            ...                       ...   ...
# 13315        Built-up  Area  Ready To Move                Whitefield   5.0
# 13316  Super built-up  Area  Ready To Move             Richards Town   4.0
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar   2.0
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar   4.0
# 13319  Super built-up  Area  Ready To Move              Doddathoguru   1.0
#
#        society  total_sqft  bath  balcony   price  total price
# ...

# %%
df.head(10)
# Out:
#               area_type   availability                  location  size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II   2.0
# 1            Plot  Area  Ready To Move          Chikka Tirupathi   4.0
# 2        Built-up  Area  Ready To Move               Uttarahalli   3.0
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli   3.0
# 4  Super built-up  Area  Ready To Move                  Kothanur   2.0
# 5  Super built-up  Area  Ready To Move                Whitefield   2.0
# 6  Super built-up  Area         18-May          Old Airport Road   4.0
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar   4.0
# 8  Super built-up  Area  Ready To Move              Marathahalli   3.0
# 9            Plot  Area  Ready To Move              Gandhi Bazar   6.0
#
#    society  total_sqft  bath  balcony   price  total price
# 0  Coomee       1056.0   2.0      1.0   39.07     41257.92
# 1  Theanmp      2600.0   5.0      3.0  120.00    312000.00
# ...

# %%
df.tail(10)
# Out:
#                   area_type   availability               location  size  \
# 13310  Super built-up  Area  Ready To Move           Rachenahalli   2.0
# 13311            Plot  Area  Ready To Move       Ramamurthy Nagar   7.0
# 13312  Super built-up  Area  Ready To Move              Bellandur   2.0
# 13313  Super built-up  Area  Ready To Move            Uttarahalli   3.0
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout   3.0
# 13315        Built-up  Area  Ready To Move             Whitefield   5.0
# 13316  Super built-up  Area  Ready To Move          Richards Town   4.0
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar   2.0
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar   4.0
# 13319  Super built-up  Area  Ready To Move           Doddathoguru   1.0
#
#        society  total_sqft  bath  balcony   price  total price
# 13310      NaN      1050.0   2.0      2.0   52.71      55345.5
# ...

# %%
df.shape
# Out:
# (13320, 10)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13320, step=1)

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price', 'total price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13316 non-null  object
#  1   availability  13316 non-null  object
#  2   location      13315 non-null  object
#  3   size          13300 non-null  float64
#  4   society       7814 non-null   object
#  5   total_sqft    13316 non-null  float64
#  6   bath          13245 non-null  float64
#  7   balcony       12709 non-null  float64
#  8   price         13316 non-null  float64
#  9   total price   13320 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.0+ MB

# %%
df.rename(columns={'size':'BHK','total_sqft':'totalsqft','area_type':'areatype','total price':'totalprice'},inplace=True)

# %%
df
# Out:
#                    areatype   availability                  location  BHK  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2.0
# 1                Plot  Area  Ready To Move          Chikka Tirupathi  4.0
# 2            Built-up  Area  Ready To Move               Uttarahalli  3.0
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  3.0
# 4      Super built-up  Area  Ready To Move                  Kothanur  2.0
# ...                     ...            ...                       ...  ...
# 13315        Built-up  Area  Ready To Move                Whitefield  5.0
# 13316  Super built-up  Area  Ready To Move             Richards Town  4.0
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2.0
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  4.0
# 13319  Super built-up  Area  Ready To Move              Doddathoguru  1.0
#
#        society  totalsqft  bath  balcony   price  totalprice
# ...

# %%
df.isna().sum()
# Out:
# areatype           4
# availability       4
# location           5
# BHK               20
# society         5506
# totalsqft          4
# bath              75
# balcony          611
# price              4
# totalprice         0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 6233

# %% [markdown]
# #### Here the data is having more null values for society and its not required to create the model so its better to drop and also those not required for the model.
# * drop society
# * drop location eventhough its important with respect to price it is important to drop here since I am not familiar with the location popularity. It is always better to true prediction than taking fasle assumptions
# * drop availability

# %%
df.drop(['society','availability','location'],axis=1,inplace=True)

# %%
df
# Out:
#                    areatype  BHK  totalsqft  bath  balcony   price  totalprice
# 0      Super built-up  Area  2.0     1056.0   2.0      1.0   39.07    41257.92
# 1                Plot  Area  4.0     2600.0   5.0      3.0  120.00   312000.00
# 2            Built-up  Area  3.0     1440.0   2.0      3.0   62.00    89280.00
# 3      Super built-up  Area  3.0     1521.0   3.0      1.0   95.00   144495.00
# 4      Super built-up  Area  2.0     1200.0   2.0      1.0   51.00    61200.00
# ...                     ...  ...        ...   ...      ...     ...         ...
# 13315        Built-up  Area  5.0     3453.0   4.0      0.0  231.00   797643.00
# 13316  Super built-up  Area  4.0     3600.0   5.0      NaN  400.00  1440000.00
# 13317        Built-up  Area  2.0     1141.0   2.0      1.0   60.00    68460.00
# 13318  Super built-up  Area  4.0     4689.0   4.0      1.0  488.00  2288232.00
# 13319  Super built-up  Area  1.0      550.0   1.0      1.0   17.00     9350.00
#
# ...

# %% [markdown]
# #### Now filling rest of the NaN values with the possible values

# %%
med_bath=df['bath'].median()
med_bath
# Out:
# 2.0

# %%
med_balcony=df['balcony'].median()
med_balcony
# Out:
# 2.0

# %%
mean_size=df['BHK'].mean()
mean_size
# Out:
# 2.803458646616541

# %%
df['bath']=df['bath'].fillna(med_bath)
df['balcony']=df['balcony'].fillna(med_balcony)
df['BHK']=df['BHK'].fillna(mean_size)

# %%
df.BHK=df.BHK.astype(int)

# %%
df.bath=df.bath.astype(int)

# %%
df.balcony=df.balcony.astype(int)

# %%
df
# Out:
#                    areatype  BHK  totalsqft  bath  balcony   price  totalprice
# 0      Super built-up  Area    2     1056.0     2        1   39.07    41257.92
# 1                Plot  Area    4     2600.0     5        3  120.00   312000.00
# 2            Built-up  Area    3     1440.0     2        3   62.00    89280.00
# 3      Super built-up  Area    3     1521.0     3        1   95.00   144495.00
# 4      Super built-up  Area    2     1200.0     2        1   51.00    61200.00
# ...                     ...  ...        ...   ...      ...     ...         ...
# 13315        Built-up  Area    5     3453.0     4        0  231.00   797643.00
# 13316  Super built-up  Area    4     3600.0     5        2  400.00  1440000.00
# 13317        Built-up  Area    2     1141.0     2        1   60.00    68460.00
# 13318  Super built-up  Area    4     4689.0     4        1  488.00  2288232.00
# 13319  Super built-up  Area    1      550.0     1        1   17.00     9350.00
#
# ...

# %%
df['areatype'].value_counts()
# Out:
# Super built-up  Area    8787
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              86
# Name: areatype, dtype: int64

# %%
df.areatype=df.areatype.replace({'Super built-up  Area':1,"Built-up  Area":2,"Plot  Area":3,"Carpet  Area":4})

# %%
#df.areatype=df.areatype.astype(int)

# %%
df
# Out:
#        areatype  BHK  totalsqft  bath  balcony   price  totalprice
# 0           1.0    2     1056.0     2        1   39.07    41257.92
# 1           3.0    4     2600.0     5        3  120.00   312000.00
# 2           2.0    3     1440.0     2        3   62.00    89280.00
# 3           1.0    3     1521.0     3        1   95.00   144495.00
# 4           1.0    2     1200.0     2        1   51.00    61200.00
# ...         ...  ...        ...   ...      ...     ...         ...
# 13315       2.0    5     3453.0     4        0  231.00   797643.00
# 13316       1.0    4     3600.0     5        2  400.00  1440000.00
# 13317       2.0    2     1141.0     2        1   60.00    68460.00
# 13318       1.0    4     4689.0     4        1  488.00  2288232.00
# 13319       1.0    1      550.0     1        1   17.00     9350.00
#
# [13320 rows x 7 columns]

# %%
df.dropna(subset=['price'],inplace=True)

# %%
df['price']=np.floor(df['price'])

# %%
df.price=df.price.astype(int)

# %%
df.isna().sum()
# Out:
# areatype      0
# BHK           0
# totalsqft     0
# bath          0
# balcony       0
# price         0
# totalprice    0
# dtype: int64

# %%
df['areatype']
# Out:
# 0        1.0
# 1        3.0
# 2        2.0
# 3        1.0
# 4        1.0
#         ...
# 13315    2.0
# 13316    1.0
# 13317    2.0
# 13318    1.0
# 13319    1.0
# Name: areatype, Length: 13316, dtype: float64

# %%
df.dtypes
# Out:
# areatype      float64
# BHK             int32
# totalsqft     float64
# bath            int32
# balcony         int32
# price           int32
# totalprice    float64
# dtype: object

# %%
df.totalprice=df.totalprice.astype(int)

# %%
df.drop(['price'],axis=1,inplace=True)

# %%
df
# Out:
#        areatype  BHK  totalsqft  bath  balcony  totalprice
# 0           1.0    2     1056.0     2        1       41257
# 1           3.0    4     2600.0     5        3      312000
# 2           2.0    3     1440.0     2        3       89280
# 3           1.0    3     1521.0     3        1      144495
# 4           1.0    2     1200.0     2        1       61200
# ...         ...  ...        ...   ...      ...         ...
# 13315       2.0    5     3453.0     4        0      797643
# 13316       1.0    4     3600.0     5        2     1440000
# 13317       2.0    2     1141.0     2        1       68460
# 13318       1.0    4     4689.0     4        1     2288232
# 13319       1.0    1      550.0     1        1        9350
#
# [13316 rows x 6 columns]

# %%
def squareft(ft):
    if ft<2000:
        return 1
    elif ft<10000:
        return 2
    elif ft<50000:
        return 3
    else:
        return 4

# %%
df['totalsqft']=df['totalsqft'].apply(squareft)

# %%
df
# Out:
#        areatype  BHK  totalsqft  bath  balcony  totalprice
# 0           1.0    2          1     2        1       41257
# 1           3.0    4          2     5        3      312000
# 2           2.0    3          1     2        3       89280
# 3           1.0    3          1     3        1      144495
# 4           1.0    2          1     2        1       61200
# ...         ...  ...        ...   ...      ...         ...
# 13315       2.0    5          2     4        0      797643
# 13316       1.0    4          2     5        2     1440000
# 13317       2.0    2          1     2        1       68460
# 13318       1.0    4          2     4        1     2288232
# 13319       1.0    1          1     1        1        9350
#
# [13316 rows x 6 columns]

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# #### From the scatterplot
# * with specific area,size of BHK,bath,balcony and the corresponding price varies
# * So total price gets affected.
# * so data can be figured out using Linear Multiple Regression

# %%
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['areatype','BHK','totalsqft','bath','balcony']],df.totalprice)
# Out:
# LinearRegression()

# %%
reg.predict([[2,3,2300,2,1]])
# Out:
# array([2.6715968e+09])

# %%
reg.coef_
# Out:
# array([  72472.59527686,  -13707.31068814, 1162053.14233321,
#          77421.69591096,   49136.67505925])

# %%
reg.intercept_
# Out:
# -1433233.8760061285

# %% [markdown]
# #### To check whether the value obtained is correct , manual check can be done using the formula
# *  y=m1x1 + m2x2 +m3x3 + b
# where m1,m2,m3 are coeficients or slope of independent variables
#         b is the intercept
# * for that reg.coef_ and reg.intercept_ can be used

# %%
5.86316326e+04*2+-5.14635522e+04*3+7.65044477e+01*2300 + 2.36730631e+05*2 +4.34206120e+04*1+-489798.9218662518
# Out:
# 165915.79044374818

# %% [markdown]
# #### So we predicted correct
