# %% [markdown]
# STUDENT PERFORMANCE

# %% [markdown]
# *This EDA(Exploratory Data Analysis) is a journey through education, data visualization and exploratory data analysis of students Exam Scores at a public school to gain maximum insights on the test preparation course using Python libraries.EDA is a process of exploring data for analysis purpose. The steps involved in EDA are :*
#
# * Preparing the Data : know the dataset, produce all details.
# * Cleaning the data for analysis: detect outliers and anomalies if any
# * Extract important variables from the data set, statistics of the data
# * Visualizations of data : this can be done in any step as per requirement
# * conclusion of analysis

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### "Student performance data set" is collected to gain on insight into
#     1. How effective is the test preparation course?
#     2. Which major factors contribute to test outcomes?
#     3. What would be the best way to improve student scores on each test?
#     4. To understand the influence of parents background on students performance
#     5. To understand whether maths score is related to writing and reading score
#     6. To extract more closer details about the student such as percentage to know the pass and fail details.

# %% [markdown]
# # Reading the csv file

# %%
student_performance=pd.read_csv("D:\MY STUDY MATERIALS\SOME DATAS FOR ANALYSIS\StudentsPerformance.csv")

# %%
student_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# #### Step 1. Preparing the data:
# * Shape
# * Attributes
# * information of data
# * index
# * Dimensions of the data
# * Size of the data
# * To know a rough about the data roughly,
# ** Statistics and pairplot

# %%
student_performance.shape
# Out:
# (1000, 8)

# %%
student_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
student_performance.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
student_performance.ndim
# Out:
# 2

# %%
student_performance.size
# Out:
# 8000

# %%
student_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
sns.pairplot(student_performance,diag_kind='kde',hue='gender')
plt.show()

# %% [markdown]
# ### A rough information about the data is clear now
# * Shape :rows-1000, columns-8==
# * Attributes:dtypes: object(5)
# * information of data : dtypes: int64(3), object(5)
# * index : rangeindex(start=0,stop=1000)
# * Dimensions of the data : 2
# * Size of the dataset: 8000
# * To know a rough about the data roughly,
# ** Statistics : all numerical details about the data
# ** Pairplot : variation with regard to male and female in general

# %% [markdown]
# # Cleaning the data
# * Null
# * Column names
# * duplicates
# * renaming

# %%
student_performance.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# 1                      False       False          False          False
# 2                      False       False          False          False
# 3                      False       False          False          False
# 4                      False       False          False          False
# ..                       ...         ...            ...            ...
# 995                    False       False          False          False
# 996                    False       False          False          False
# 997                    False       False          False          False
# 998                    False       False          False          False
# 999                    False       False          False          False
#
# [1000 rows x 8 columns]

# %%
student_performance.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
student_performance.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
student_performance.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
student_performance.duplicated().sum()
# Out:
# 0

# %%
student_performance.drop(['lunch'],axis=1,inplace=True)
student_performance
# Out:
#      gender race/ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 3      male        group A          associate's degree
# 4      male        group C                some college
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 7 columns]

# %% [markdown]
# # Extracting Datas
# * unique values
#     - of each column
#     - with in columns
# *

# %%
student_performance.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
student_performance['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
student_performance['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
student_performance['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
student_performance['test preparation course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
gender_count=student_performance['gender'].value_counts()
gender_count
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
race_count=student_performance['race/ethnicity'].value_counts()
race_count
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
parentallevel_count=student_performance['parental level of education'].value_counts()
parentallevel_count
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
test_prep_count=student_performance['test preparation course'].value_counts()
test_prep_count
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %% [markdown]
# # Exploration Data Analysis

# %% [markdown]
# 1. How effective is the test preparation course?
# * Looking on to the number of individuals who completed the test preparation course is comparatively one third of the population.
# * Further checking the relation with ethnicity

# %%
student_performance.rename(columns={'race/ethnicity':'race_ethnicity'},inplace=True)

# %%
testprep_course=student_performance.groupby(['race_ethnicity','test preparation course'])['test preparation course'].count()
testprep_course=pd.DataFrame(testprep_course)
testprep_course
# Out:
#                                         test preparation course
# race_ethnicity test preparation course
# group A        completed                                     31
#                none                                          58
# group B        completed                                     68
#                none                                         122
# group C        completed                                    117
#                none                                         202
# group D        completed                                     82
#                none                                         180
# group E        completed                                     60
#                none                                          80

# %% [markdown]
# #### Its clear that
# * Group C has completed the most test preparation course
# * Group E the least
# ###### To have more clarity visualization can be done

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x="race_ethnicity", hue='test preparation course',data=student_performance)
plt.legend()
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x="gender", hue='test preparation course', data=student_performance)
plt.show()

# %% [markdown]
# ### Conclusions about test preparation course:
# * more students are not completed
# * Among completed students group C part is the most
#   group E the least, so it was effective with group C
# * Females completed the most compared to males and those     who did not complete is not a substantial difference

# %% [markdown]
# ### Factors basically implies the corelation between the variables
# * whether score of maths, writing and reading related
# * whether in which group an individual matters
# * parents education influence test scores

# %%
sns.heatmap(student_performance.corr(),cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# * reading and writing scores has a high positive corelation almost to 1

# %%
read_math=sns.lineplot(x='reading score',y='math score',data=student_performance)
write_math=sns.lineplot(x='writing score',y='math score',data=student_performance)
plt.title("Writing and Reading with respect to Mathscore")  # HEADING
plt.xlabel("Reading score")  # X LABEL
plt.ylabel("Math score")  #Y LABEL
plt.legend(["read_math","write_math"]) 
plt.show()

# %% [markdown]
# * "Writing and Reading" relates to "Maths score" almost the same so increase in both benefits alot. It is a good practice to read and write while practicing to improve the marks

# %%
#parental influence =p
p=student_performance.groupby(['parental level of education','test preparation course'])['parental level of education'].count()
p=pd.DataFrame(p)
p
# Out:
#                                                      parental level of education
# parental level of education test preparation course
# associate's degree          completed                                         82
#                             none                                             140
# bachelor's degree           completed                                         46
#                             none                                              72
# high school                 completed                                         56
#                             none                                             140
# master's degree             completed                                         20
#                             none                                              39
# some college                completed                                         77
#                             none                                             149
# some high school            completed                                         77
#                             none                                             102

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x="parental level of education", hue='test preparation course', data=student_performance,palette="bright")
plt.show()

# %% [markdown]
# ### visualising number of males and females in the dataset

# %%
plt.subplots(figsize=(15,5))
student_performance['gender'].value_counts(normalize=True)
student_performance['gender'].value_counts(dropna=False).plot.bar(color='cyan')
plt.title('comparison of Males and Females')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Detecting Outliers

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.distplot(student_performance['math score'])
plt.subplot(1,3,2)
sns.distplot(student_performance['reading score'])
plt.subplot(1,3,3)
sns.distplot(student_performance['writing score'])
plt.show()

# %% [markdown]
# #### Clearly, there is no skewness in the columns considered

# %% [markdown]
# ### lets check the data grouping them according to gender and extract information across it

# %%
student_performance_grouped=student_performance.groupby('gender')
females=student_performance_grouped.get_group('female')
females
# Out:
#      gender race_ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 5    female        group B          associate's degree
# 6    female        group B                some college
# ..      ...            ...                         ...
# 993  female        group D           bachelor's degree
# 995  female        group E             master's degree
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 5                      none          71             83             78
# 6                 completed          88             95             92
# ..                      ...         ...            ...            ...
# 993                    none          62             72             74
# 995               completed          88             99             95
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [518 rows x 7 columns]

# %%
females.describe()
# Out:
#        math score  reading score  writing score
# count  518.000000     518.000000     518.000000
# mean    63.633205      72.608108      72.467181
# std     15.491453      14.378245      14.844842
# min      0.000000      17.000000      10.000000
# 25%     54.000000      63.250000      64.000000
# 50%     65.000000      73.000000      74.000000
# 75%     74.000000      83.000000      82.000000
# max    100.000000     100.000000     100.000000

# %%
student_performance_grouped=student_performance.groupby('gender')
males=student_performance_grouped.get_group('male')
males
# Out:
#     gender race_ethnicity parental level of education test preparation course  \
# 3     male        group A          associate's degree                    none
# 4     male        group C                some college                    none
# 7     male        group B                some college                    none
# 8     male        group D                 high school               completed
# 10    male        group C          associate's degree                    none
# ..     ...            ...                         ...                     ...
# 985   male        group A                 high school                    none
# 987   male        group E            some high school               completed
# 990   male        group E                 high school               completed
# 994   male        group A                 high school                    none
# 996   male        group C                 high school                    none
#
#      math score  reading score  writing score
# 3            47             57             44
# 4            76             78             75
# 7            40             43             39
# 8            64             64             67
# 10           58             54             52
# ..          ...            ...            ...
# 985          57             51             54
# 987          81             75             76
# 990          86             81             75
# 994          63             63             62
# 996          62             55             55
#
# [482 rows x 7 columns]

# %%
Average_female_mathscore=females['math score'].mean()
print("Average_female_mathscore=",Average_female_mathscore)
Average_female_readingscore=females['reading score'].mean()
print("Average_female_readingscore=",Average_female_readingscore)
Average_female_writingscore=females['writing score'].mean()
print("Average_female_writingscore=",Average_female_writingscore)
# Out:
# Average_female_mathscore= 63.633204633204635
# Average_female_readingscore= 72.60810810810811
# Average_female_writingscore= 72.46718146718146

# %%
males.describe()
# Out:
#        math score  reading score  writing score
# count  482.000000     482.000000     482.000000
# mean    68.728216      65.473029      63.311203
# std     14.356277      13.931832      14.113832
# min     27.000000      23.000000      15.000000
# 25%     59.000000      56.000000      53.000000
# 50%     69.000000      66.000000      64.000000
# 75%     79.000000      75.000000      73.750000
# max    100.000000     100.000000     100.000000

# %%
Average_male_mathscore=males['math score'].mean()
print("Average_male_mathscore=",Average_male_mathscore)
Average_male_readingscore=males['reading score'].mean()
print("Average_male_readingscore=",Average_male_readingscore)
Average_male_writingscore=males['writing score'].mean()
print("Average_male_writingscore=",Average_male_writingscore)
# Out:
# Average_male_mathscore= 68.72821576763485
# Average_male_readingscore= 65.47302904564316
# Average_male_writingscore= 63.31120331950208

# %%
student_performance.groupby(['gender']).agg(['min','median','max'])
# Out:
#        math score             reading score             writing score         \
#               min median  max           min median  max           min median
# gender
# female          0   65.0  100            17   73.0  100            10   74.0
# male           27   69.0  100            23   66.0  100            15   64.0
#
#
#         max
# gender
# female  100
# male    100

# %% [markdown]
# #### Obviously, mathscore indicates well with males where as reading and writing skill are good with females comparitively

# %% [markdown]
# # Setting a pass marks to check the data more closely

# %%
plt.subplots(figsize=(15,8))
pass_marks=60 # for all three scores
student_performance['pass_math=40']=np.where(student_performance['math score']<pass_marks,'fail','pass')
student_performance['pass_math=40'].value_counts(dropna=False).plot.bar(color='black',figsize=(5,3))
plt.title('comparison of students passed or failed in maths ')
plt.xlabel('status')
plt.ylabel('count')
plt.show()

# %% [markdown]
# #### Now, Data set of Student performance will have a new columns for reading,writing and math  which will clearly give an idea about the student pass/fail detail in the test performance

# %%
student_performance

# %% [markdown]
# ## computing the total marks

# %%
pass_marks=60
student_performance['pass_math'] = np.where(student_performance['math score']< pass_marks, 'Fail', 'Pass')
student_performance['pass_math'].value_counts().plot.pie(colors = ['lightblue', 'lightgreen'])

plt.title('Pass/Fail in Maths', fontweight = 30, fontsize = 20)
plt.xlabel('status')
plt.ylabel('count')
plt.show()
student_performance['pass_reading'] = np.where(student_performance['reading score']< pass_marks, 'Fail', 'Pass')
student_performance['pass_reading'].value_counts(dropna = False).plot.pie(colors = ['pink', 'yellow'])

plt.title('Pass/Fail in Reading', fontweight = 30, fontsize = 20)
plt.xlabel('status')
plt.ylabel('count')
plt.show()
student_performance['pass_writing'] = np.where(student_performance['writing score']< pass_marks, 'Fail', 'Pass')
student_performance['pass_writing'].value_counts(dropna = False).plot.pie(colors = ['orange', 'gray'])

plt.title('Pass/Fail in Writing', fontweight = 30, fontsize = 20)
plt.xlabel('status')
plt.ylabel('count')
plt.show()

# %%
student_performance['Total Score']=student_performance['math score']+student_performance['reading score']+student_performance['writing score']
student_performance
# Out:
#      gender race_ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 3      male        group A          associate's degree
# 4      male        group C                some college
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#     pass_math=40 pass_math pass_reading pass_writing  Total Score
# 0           pass      Pass         Pass         Pass          218
# 1           pass      Pass         Pass         Pass          247
# 2           pass      Pass         Pass         Pass          278
# 3           fail      Fail         Fail         Fail          148
# 4           pass      Pass         Pass         Pass          229
# ..           ...       ...          ...          ...          ...
# 995         pass      Pass         Pass         Pass          282
# 996         pass      Pass         Fail         Fail          172
# 997         fail      Fail         Pass         Pass          195
# 998         pass      Pass         Pass         Pass          223
# 999         pass      Pass         Pass         Pass          249
#
# [1000 rows x 12 columns]

# %%
from math import *
student_performance['Percentage']=student_performance['Total Score']/3
for i in range (0,1000):
    student_performance['Percentage'][i]=ceil(student_performance['Percentage'][i])

# %%
student_performance
# Out:
#      gender race_ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 3      male        group A          associate's degree
# 4      male        group C                some college
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#     pass_math=40 pass_math pass_reading pass_writing  Total Score  Percentage
# 0           pass      Pass         Pass         Pass          218        73.0
# 1           pass      Pass         Pass         Pass          247        83.0
# 2           pass      Pass         Pass         Pass          278        93.0
# 3           fail      Fail         Fail         Fail          148        50.0
# 4           pass      Pass         Pass         Pass          229        77.0
# ..           ...       ...          ...          ...          ...         ...
# 995         pass      Pass         Pass         Pass          282        94.0
# 996         pass      Pass         Fail         Fail          172        58.0
# 997         fail      Fail         Pass         Pass          195        65.0
# 998         pass      Pass         Pass         Pass          223        75.0
# 999         pass      Pass         Pass         Pass          249        83.0
#
# [1000 rows x 13 columns]

# %%
student_performance['percentage'] = student_performance['Total Score']/3

for i in range(0, 1000):
   student_performance['percentage'][i] = ceil(student_performance['percentage'][i])

plt.rcParams['figure.figsize'] = (15, 9)
sns.distplot(student_performance['percentage'], color = 'orange')

plt.title('Comparison of percentage scored by all the students', fontweight = 30, fontsize = 20)
plt.xlabel('Percentage scored')
plt.ylabel('Count')
plt.show()

# %%
student_performance['status'] = student_performance.apply(lambda x : 'Fail' if x['pass_math'] == 'Fail' or 
                           x['pass_reading'] == 'Fail' or x['pass_writing'] == 'Fail'
                           else 'pass', axis = 1)

student_performance['status'].value_counts(dropna = False)
# Out:
# pass    603
# Fail    397
# Name: status, dtype: int64

# %%
student_performance
# Out:
#      gender race_ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 3      male        group A          associate's degree
# 4      male        group C                some college
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#     pass_math=40 pass_math pass_reading pass_writing  Total Score  Percentage  \
# 0           pass      Pass         Pass         Pass          218        73.0
# 1           pass      Pass         Pass         Pass          247        83.0
# 2           pass      Pass         Pass         Pass          278        93.0
# 3           fail      Fail         Fail         Fail          148        50.0
# 4           pass      Pass         Pass         Pass          229        77.0
# ..           ...       ...          ...          ...          ...         ...
# 995         pass      Pass         Pass         Pass          282        94.0
# 996         pass      Pass         Fail         Fail          172        58.0
# 997         fail      Fail         Pass         Pass          195        65.0
# 998         pass      Pass         Pass         Pass          223        75.0
# 999         pass      Pass         Pass         Pass          249        83.0
#
#      percentage status
# 0          73.0   pass
# 1          83.0   pass
# 2          93.0   pass
# 3          50.0   Fail
# 4          77.0   pass
# ..          ...    ...
# 995        94.0   pass
# 996        58.0   Fail
# 997        65.0   Fail
# 998        75.0   pass
# 999        83.0   pass
#
# [1000 rows x 15 columns]

# %%
def getgrade(percentage, status):
  if status == 'Fail':
    return 'E'
  if(percentage >= 90):
    return 'O'
  if(percentage >= 80):
    return 'A'
  if(percentage >= 70):
    return 'B'
  if(percentage >= 60):
    return 'C'
  if(percentage >= 40):
    return 'D'
  else :
    return 'E'

student_performance['grades'] = student_performance.apply(lambda x: getgrade(x['percentage'], x['status']), axis = 1 )

student_performance['grades'].value_counts()
# Out:
# E    397
# B    253
# A    156
# C    136
# O     58
# Name: grades, dtype: int64

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x="parental level of education", hue='status', data=student_performance,palette="bright")
plt.show()

# %% [markdown]
# ##### Suprisingly, there was no big effect of parents education with their children even though it can be seen that children whose parents completed their masters has no fail rate

# %% [markdown]
# #### CONCLUSION:
# * Test preparation course gives the result depending upon the race/ethnicity they are in and even the number of students in each group differs.
# * Reading writing and math scores are correlated so to improve the scores students should make a habit of reading and writing to increase their skill
# * In general, scores taken by males and females do not differ by completion rate and pass rate.
# * Lastly, Parents education has no effect on their children which was actually a surprising fact
