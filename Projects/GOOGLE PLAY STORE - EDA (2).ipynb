# %% [markdown]
# # Google Play Store

# %% [markdown]
#    #####          This EDA is a journey through almost 10000 Apps in the Google play list to gain maximum insights on the App contents using Python libraries.EDA is a process of exploring data for analysis purpose. The steps involved in EDA are
#                     *Preparing the Data : know the dataset, produce all details.
#                     *Cleaning the data for analysis: detect outliers and anomalies if any
#                     *Extract important variables from the data set, statistics of the data
#                     *Visualizations of data : this can be done in any step as per requirement
#                     *conclusion of analysis

# %% [markdown]
# ##### Importing libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading the csv file

# %% [markdown]
#  ### "Google Play Store" data is collected to gain on insight into the
#         >Highly installed Apps
#         >Whether it is paid or for free
#         >Are these Apps child safe

# %% [markdown]
# #### step1: Preparing the data

# %%
GPS=pd.read_csv("D:\MY STUDY MATERIALS\SOME DATAS FOR ANALYSIS\GooglePlaystore.csv")

# %%
GPS
# Out:
#                                                     App  Category  Rating  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook         0     4.1
# 1                                   Coloring book moana         0     3.9
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...         0     4.7
# 3                                 Sketch - Draw & Paint         0     4.5
# 4                 Pixel Draw - Number Art Coloring Book         0     4.3
# ...                                                 ...       ...     ...
# 9654                                   Sya9a Maroc - FR        11     4.5
# 9655                   Fr. Mike Schmitz Audio Teachings        11     5.0
# 9656                             Parkinson Exercices FR        20     NaN
# 9657                      The SCP Foundation DB fr nn5n         3     4.5
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology        18     4.5
#
#       Reviews  Size  Installs  Type  Price Content Rating  Genres  ...  \
# ...

# %% [markdown]
# #### Before starting exploration it is important to check whether data is organised
#             > Step2: Cleaning data : Study and understand the data and the necessity for this data analysis
#                     * shape
#                     * attributes
#                     *information
#                     *null rows
#                     *duplicates and soon.

# %% [markdown]
# ####  Shape of the Google play data set: row and column

# %%
GPS.shape
# Out:
# (9659, 23)

# %% [markdown]
# ### Checking attributes in the set

# %%
GPS.dtypes
# Out:
# App                         object
# Category                     int64
# Rating                     float64
# Reviews                      int64
# Size                       float64
# Installs                     int64
# Type                         int64
# Price                      float64
# Content Rating              object
# Genres                       int64
# Last Updated                object
# Current Ver                  int64
# Android Ver                  int64
# Last Updated Year            int64
# Last Updated Year,Month      int64
# Category                    object
# Type of access              object
# Genres categorical          object
# Current Ver ext             object
# Android Ver ext             object
# Last Updated Years          object
# No_reviews_count             int64
# Reviews_present_count        int64
# dtype: object

# %% [markdown]
# ### Changing irrelevant names

# %%
GPS.rename(columns={'Content Rating':'genretargeted'},inplace=True)

# %%
GPS.drop(['Size'],axis=1,inplace=True)

# %%
GPS.drop(['Last Updated Years'],axis=1,inplace=True)

# %%
GPS.drop(['Last Updated Year,Month'],axis=1,inplace=True)

# %%
GPS.drop(['Last Updated Year'],axis=1,inplace=True)

# %%
GPS.drop(['Category'],axis=1,inplace=True)

# %%
GPS.drop(['Last Updated'],axis=1,inplace=True)

# %%
GPS.drop(['Type'],axis=1,inplace=True)

# %% [markdown]
# ###### A Relevant Google Play Dataset is obtained

# %%
GPS
# Out:
#                                                     App  Rating  Reviews  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook     4.1      159
# 1                                   Coloring book moana     3.9      967
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7    87510
# 3                                 Sketch - Draw & Paint     4.5   215644
# 4                 Pixel Draw - Number Art Coloring Book     4.3      967
# ...                                                 ...     ...      ...
# 9654                                   Sya9a Maroc - FR     4.5       38
# 9655                   Fr. Mike Schmitz Audio Teachings     5.0        4
# 9656                             Parkinson Exercices FR     NaN        3
# 9657                      The SCP Foundation DB fr nn5n     4.5      114
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology     4.5   398307
#
#       Installs  Price genretargeted  Genres  Current Ver  Android Ver  \
# ...

# %%
GPS.index
# Out:
# RangeIndex(start=0, stop=9659, step=1)

# %% [markdown]
# ###### Dimensions of the data

# %%
GPS.ndim
# Out:
# 2

# %% [markdown]
# #### Size of the dataset

# %%
GPS.size
# Out:
# 154544

# %% [markdown]
# ### Data Information

# %%
GPS_info=GPS.info()
GPS_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   App                    9659 non-null   object
#  1   Rating                 8196 non-null   float64
#  2   Reviews                9659 non-null   int64
#  3   Installs               9659 non-null   int64
#  4   Price                  9659 non-null   float64
#  5   genretargeted          9659 non-null   object
#  6   Genres                 9659 non-null   int64
#  7   Current Ver            9659 non-null   int64
#  8   Android Ver            9659 non-null   int64
#  9   Category               9659 non-null   object
#  10  Type of access         9658 non-null   object
#  11  Genres categorical     9659 non-null   object
#  12  Current Ver ext        9651 non-null   object
#  13  Android Ver ext        9657 non-null   object
# ...

# %% [markdown]
# ####  Column names of the Google play data set

# %%
GPS.columns
# Out:
# Index(['App', 'Rating', 'Reviews', 'Installs', 'Price', 'genretargeted',
#        'Genres', 'Current Ver', 'Android Ver', 'Category ', 'Type of access',
#        'Genres categorical', 'Current Ver ext', 'Android Ver ext',
#        'No_reviews_count', 'Reviews_present_count'],
#       dtype='object')

# %% [raw]
# Since the data is a big population it is better to take samples out of it for further analysis and it is always good to have a scatter plot on the requirement of the data.

# %%
import seaborn as sns

# %%
sns.pairplot(GPS)
plt.show()

# %%
sns.relplot(x='Rating',y='Reviews',col='genretargeted', hue='Type of access',kind='line',data=GPS)
plt.show()

# %%
sns.scatterplot(x='Type of access',y='Installs',data=GPS)
# Out:
# <AxesSubplot:xlabel='Type of access', ylabel='Installs'>

# %% [markdown]
# ###### This give a rough idea about the dataset

# %% [raw]
#             1.Highly installed Apps are almost free
#             2. most of the free installed app comes under the category of teen and evryone- 10+

# %% [markdown]
# ##### Analysing the data from 400 random samples to predict the result about population

# %%
GPS_sample=GPS.sample(400)
GPS_sample
# Out:
#                                 App  Rating  Reviews   Installs  Price  \
# 6800              CT Abdomen Pelvis     4.0       36      10000   0.00
# 3549         [substratum] Vacuum: P     4.4      230       1000   1.49
# 2413  World Travel Guide by Triposo     4.4     6012     500000   0.00
# 5330              Real DJ Simulator     4.0    68664   10000000   0.00
# 6653       C.P. CERVANTES (TOBARRA)     NaN        0          5   0.00
# ...                             ...     ...      ...        ...    ...
# 5074            Free GPS Navigation     4.2   618562   50000000   0.00
# 4085              AE Fishing Hunter     4.4       14       1000   0.00
# 3455    M Launcher -Marshmallow 6.0     4.4    37234    1000000   0.00
# 2269               Photo Editor Pro     4.3  1871416  100000000   0.00
# 903    Mint: Budget, Bills, Finance     4.3   129304    5000000   0.00
#
#      genretargeted  Genres  Current Ver  Android Ver            Category   \
# ...

# %%
GPS_sample.head(300)
# Out:
#                                  App  Rating  Reviews  Installs  Price  \
# 6800               CT Abdomen Pelvis     4.0       36     10000   0.00
# 3549          [substratum] Vacuum: P     4.4      230      1000   1.49
# 2413   World Travel Guide by Triposo     4.4     6012    500000   0.00
# 5330               Real DJ Simulator     4.0    68664  10000000   0.00
# 6653        C.P. CERVANTES (TOBARRA)     NaN        0         5   0.00
# ...                              ...     ...      ...       ...    ...
# 4571   Guns of Boom - Online Shooter     4.6  1226514  10000000   0.00
# 6570                      Wuwu & Co.     NaN        9       100   2.99
# 6834  Interactive CT and MRI Anatomy     3.4       35      1000  15.46
# 9057         Video Downloader for FB     4.3       53      5000   0.00
# 3895                          Z City     4.3     3976    100000   0.00
#
#      genretargeted  Genres  Current Ver  Android Ver         Category   \
# ...

# %% [markdown]
# ### Checking for null rows and hence its total

# %%
GPS_sample.isnull()
# Out:
#         App  Rating  Reviews  Installs  Price  genretargeted  Genres  \
# 6800  False   False    False     False  False          False   False
# 3549  False   False    False     False  False          False   False
# 2413  False   False    False     False  False          False   False
# 5330  False   False    False     False  False          False   False
# 6653  False    True    False     False  False          False   False
# ...     ...     ...      ...       ...    ...            ...     ...
# 5074  False   False    False     False  False          False   False
# 4085  False   False    False     False  False          False   False
# 3455  False   False    False     False  False          False   False
# 2269  False   False    False     False  False          False   False
# 903   False   False    False     False  False          False   False
#
#       Current Ver  Android Ver  Category   Type of access  Genres categorical  \
# ...

# %%
GPS_sample.isnull().sum()
# Out:
# App                       0
# Rating                   67
# Reviews                   0
# Installs                  0
# Price                     0
# genretargeted             0
# Genres                    0
# Current Ver               0
# Android Ver               0
# Category                  0
# Type of access            0
# Genres categorical        0
# Current Ver ext           0
# Android Ver ext           1
# No_reviews_count          0
# Reviews_present_count     0
# dtype: int64

# %% [markdown]
# ##### Droping those rows which are filled with null character

# %%
GPS_sample.dropna(subset=['Rating'],inplace=True)

# %%
GPS_sample
# Out:
#                                  App  Rating  Reviews   Installs  Price  \
# 6800               CT Abdomen Pelvis     4.0       36      10000   0.00
# 3549          [substratum] Vacuum: P     4.4      230       1000   1.49
# 2413   World Travel Guide by Triposo     4.4     6012     500000   0.00
# 5330               Real DJ Simulator     4.0    68664   10000000   0.00
# 3247  EBookDroid - PDF & DJVU Reader     4.5    75951    5000000   0.00
# ...                              ...     ...      ...        ...    ...
# 5074             Free GPS Navigation     4.2   618562   50000000   0.00
# 4085               AE Fishing Hunter     4.4       14       1000   0.00
# 3455     M Launcher -Marshmallow 6.0     4.4    37234    1000000   0.00
# 2269                Photo Editor Pro     4.3  1871416  100000000   0.00
# 903     Mint: Budget, Bills, Finance     4.3   129304    5000000   0.00
#
#      genretargeted  Genres  Current Ver  Android Ver            Category   \
# ...

# %% [markdown]
# #### Rechecking for null and then drop if any

# %%
GPS_sample.isnull().sum()
# Out:
# App                      0
# Rating                   0
# Reviews                  0
# Installs                 0
# Price                    0
# genretargeted            0
# Genres                   0
# Current Ver              0
# Android Ver              0
# Category                 0
# Type of access           0
# Genres categorical       0
# Current Ver ext          0
# Android Ver ext          1
# No_reviews_count         0
# Reviews_present_count    0
# dtype: int64

# %%
GPS_sample.dropna(subset=['Android Ver ext'],inplace=True)

# %%
GPS_sample.isnull().sum()
# Out:
# App                      0
# Rating                   0
# Reviews                  0
# Installs                 0
# Price                    0
# genretargeted            0
# Genres                   0
# Current Ver              0
# Android Ver              0
# Category                 0
# Type of access           0
# Genres categorical       0
# Current Ver ext          0
# Android Ver ext          0
# No_reviews_count         0
# Reviews_present_count    0
# dtype: int64

# %% [markdown]
# # Data is free from "Null values"

# %% [markdown]
# #### Next step is to check for "Duplicates"

# %% [markdown]
# ## Checking for duplicates

# %%
GPS_sample.duplicated()
# Out:
# 6800    False
# 2413    False
# 5330    False
# 3247    False
# 5318    False
#         ...
# 5074    False
# 4085    False
# 3455    False
# 2269    False
# 903     False
# Length: 332, dtype: bool

# %% [markdown]
# ###### Since the data is big its always good to check for duplicated total

# %%
GPS_sample.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  #### Data is out of null and duplicated values and its now ready for EXTRACTION

# %%
GPS_sample
# Out:
#                                  App  Rating  Reviews   Installs  Price  \
# 6800               CT Abdomen Pelvis     4.0       36      10000    0.0
# 2413   World Travel Guide by Triposo     4.4     6012     500000    0.0
# 5330               Real DJ Simulator     4.0    68664   10000000    0.0
# 3247  EBookDroid - PDF & DJVU Reader     4.5    75951    5000000    0.0
# 5318  Real Casino:Slot,Keno,BJ,Poker     4.1      341      50000    0.0
# ...                              ...     ...      ...        ...    ...
# 5074             Free GPS Navigation     4.2   618562   50000000    0.0
# 4085               AE Fishing Hunter     4.4       14       1000    0.0
# 3455     M Launcher -Marshmallow 6.0     4.4    37234    1000000    0.0
# 2269                Photo Editor Pro     4.3  1871416  100000000    0.0
# 903     Mint: Budget, Bills, Finance     4.3   129304    5000000    0.0
#
#      genretargeted  Genres  Current Ver  Android Ver            Category   \
# ...

# %% [markdown]
# ### Step 3: Extracting Data from Google Play Store dataset

# %% [markdown]
# ##### Checking for number of unique values in dataset

# %%
GPS_sample.nunique()
# Out:
# App                      332
# Rating                    27
# Reviews                  300
# Installs                  19
# Price                     13
# genretargeted              4
# Genres                    60
# Current Ver              225
# Android Ver               22
# Category                  33
# Type of access             2
# Genres categorical        60
# Current Ver ext          221
# Android Ver ext           22
# No_reviews_count          20
# Reviews_present_count     19
# dtype: int64

# %% [markdown]
# ###### Unique elements from required column and their corresponding count

# %%
GPS_sample['Type of access'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
GPS_sample['genretargeted'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+'], dtype=object)

# %%
GPS_sample['Genres categorical'].unique()
# Out:
# array(['Medical', 'Travel & Local', 'Simulation', 'Productivity',
#        'Casino', 'Photography', 'Action', 'Books & Reference',
#        'Food & Drink', 'Tools', 'Personalization', 'Communication',
#        'Parenting', 'Trivia', 'Education;Pretend Play', 'Education',
#        'Strategy', 'Video Players & Editors', 'Parenting;Music & Video',
#        'Puzzle', 'Arcade;Action & Adventure', 'Maps & Navigation',
#        'Education;Education', 'Lifestyle', 'Finance', 'Health & Fitness',
#        'Dating', 'Comics', 'Casual', 'Arcade', 'Entertainment',
#        'Shopping', 'Racing;Action & Adventure', 'Business',
#        'House & Home', 'Sports', 'Events', 'Auto & Vehicles',
#        'Casual;Action & Adventure', 'Racing', 'Adventure', 'Weather',
#        'News & Magazines', 'Educational;Education', 'Social',
#        'Art & Design', 'Word', 'Libraries & Demo', 'Educational',
#        'Adventure;Action & Adventure', 'Role Playing', 'Board',
# ...

# %% [markdown]
# #### Calculating the count of each columns subcategory as per requirement

# %%
GPS_type=GPS_sample['Type of access'].value_counts()
GPS_type
# Out:
# Free    309
# Paid     23
# Name: Type of access, dtype: int64

# %%
GPS_content_rating=GPS_sample['genretargeted'].value_counts()
GPS_content_rating
# Out:
# Everyone        255
# Teen             48
# Mature 17+       17
# Everyone 10+     12
# Name: genretargeted, dtype: int64

# %%
GPS_genres=GPS_sample['Genres categorical'].value_counts()
GPS_genres
# Out:
# Tools                            27
# Entertainment                    21
# Medical                          15
# Education                        14
# Finance                          14
# Action                           13
# Sports                           13
# Lifestyle                        13
# Productivity                     11
# Photography                      11
# Simulation                       11
# Personalization                  11
# Communication                    10
# Dating                            8
# Health & Fitness                  8
# Video Players & Editors           8
# Strategy                          7
# Business                          7
# Books & Reference                 7
# News & Magazines                  6
# Casual                            6
# Arcade                            6
# Puzzle                            5
# Adventure                         5
# Racing                            5
# Social                            5
# ...

# %% [markdown]
# ### Purpose of Data set analysis

# %% [markdown]
# ####  1. To show highly installed Apps

# %%
high_installed_apps=GPS_sample.sort_values('Installs',ascending=False)
high_installed_apps
# Out:
#                                App  Rating   Reviews    Installs  Price  \
# 701              Google Play Games     4.3   7165362  1000000000    0.0
# 2507                        Google     4.4   8033493  1000000000    0.0
# 306                Viber Messenger     4.3  11334799   500000000    0.0
# 2269              Photo Editor Pro     4.3   1871416   100000000    0.0
# 1424        Hungry Shark Evolution     4.5   6074334   100000000    0.0
# ...                            ...     ...       ...         ...    ...
# 8074  UP EB Bill Payment & Details     5.0         3          50    0.0
# 7251                 DF Glue Board     5.0         1          10    0.0
# 8145                      EC Mover     5.0         5          10    0.0
# 1962             Clinic Doctor EHr     5.0         2           5    0.0
# 1932           KBA-EZ Health Guide     5.0         4           1    0.0
#
#      genretargeted  Genres  Current Ver  Android Ver      Category   \
# ...

# %% [markdown]
# ###### From the above analysed it can be seen that  most installed App is "Google play games and google"

# %% [markdown]
# ### step4: Visualizing the data for the App that is installed the most

# %%
high_installed_apps_sample=high_installed_apps.head()
high_installed_apps_sample
# Out:
#                          App  Rating   Reviews    Installs  Price  \
# 701        Google Play Games     4.3   7165362  1000000000    0.0
# 2507                  Google     4.4   8033493  1000000000    0.0
# 306          Viber Messenger     4.3  11334799   500000000    0.0
# 2269        Photo Editor Pro     4.3   1871416   100000000    0.0
# 1424  Hungry Shark Evolution     4.5   6074334   100000000    0.0
#
#      genretargeted  Genres  Current Ver  Android Ver      Category   \
# 701           Teen      51         2750           32  ENTERTAINMENT
# 2507      Everyone     107         2750           32          TOOLS
# 306       Everyone      35         2750           32  COMMUNICATION
# 2269      Everyone      80         2750           32    PHOTOGRAPHY
# 1424          Teen       6         2350           17           GAME
#
#      Type of access Genres categorical     Current Ver ext  \
# 701            Free      Entertainment  Varies with device
# ...

# %%
plt.figure(figsize=(6,10))
sns.barplot(y=high_installed_apps_sample['App'],x=high_installed_apps_sample['Installs'])
plt.title('Apps vs high installs',fontsize=20,color='b')
plt.ylabel('App',fontsize=20)
plt.xlabel('Installs',fontsize=20)
plt.show()

# %% [markdown]
# ### 2. A study to know about on what basis App has more installation rate

# %% [markdown]
# ###### * Is it due to current version ?

# %%
GPS_sample['Installs'].corr(GPS_sample['Current Ver'])
# Out:
# 0.17601158556658403

# %%
    sns.relplot(x='Android Ver',y='Current Ver',col='Installs',kind='line',data=GPS_sample.head(10))
    plt.show()

# %% [markdown]
# #### They were less corelated

# %% [markdown]
# ##### Is it due to wide range of free availability of Apps?

# %%
GPS_sample_compare=GPS_sample.groupby(['Type of access'])['Installs'].sum()
GPS_sample_compare=pd.DataFrame(GPS_sample_compare)
GPS_sample_compare
# Out:
#                   Installs
# Type of access
# Free            4027808576
# Paid               1323850

# %% [markdown]
# ##### Free installation was much more than the paid and to confirm visualisation is done

# %%
plt.figure(figsize=(10,10))
labels=GPS_sample['Type of access'].value_counts(sort=True).index
sizes=GPS_sample['Type of access'].value_counts(sort=True)
explode=(0.5,0)
colors=['green','blue']
plt.pie(sizes,labels=labels,explode=explode,colors=colors,shadow=True,startangle=0)
plt.title('Installation v/s Type of access',size=20)
plt.legend()
plt.show()

# %% [markdown]
# ##### *****This gave a clear idea that free apps were installed too much compared to paid ones ****

# %%
    
sns.lineplot(x='Installs',y='Price',hue='Type of access',data=GPS_sample.head(300))
plt.show()

# %% [raw]
# Seeing the linear graph between the price or type of acess with the installed Apps

# %% [markdown]
# #### 3.Comparing category with genretargeted to know whether the app are  "child safe"

# %%
GPS_sample_compare=GPS_sample.groupby(['genretargeted'])['Genres categorical'].count()
GPS_sample_compare=pd.DataFrame(GPS_sample_compare)
GPS_sample_compare
# Out:
#                Genres categorical
# genretargeted
# Everyone                      255
# Everyone 10+                   12
# Mature 17+                     17
# Teen                           48

# %%
from matplotlib import style
style.use('ggplot')
plt.plot(GPS_sample_compare,'o-.g')
plt.title("genretargeted V/s genres category")
plt.xlabel("genretargeted")
plt.ylabel("genres category")
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Maximum Apps  are targeted for Everyone indicates it has maximum of its contents availale for all

# %%
GPS_sample_compare=GPS_sample.groupby(['genretargeted'])['Rating'].count()
GPS_sample_compare=pd.DataFrame(GPS_sample_compare)
GPS_sample_compare
# Out:
#                Rating
# genretargeted
# Everyone          255
# Everyone 10+       12
# Mature 17+         17
# Teen               48

# %% [markdown]
# #####  Genre versus " Reviews and Rating "

# %% [markdown]
# #### Grouping the data according to rating

# %%
GPS_sample_compare=GPS_sample.groupby(['Genres categorical'])['Rating'].count().sort_values(ascending=False)
GPS_Top_rating=GPS_sample_compare.head(10)
GPS_Top_rating=pd.DataFrame(GPS_Top_rating)
GPS_Top_rating
# Out:
#                     Rating
# Genres categorical
# Tools                   27
# Entertainment           21
# Medical                 15
# Finance                 14
# Education               14
# Sports                  13
# Lifestyle               13
# Action                  13
# Simulation              11
# Photography             11

# %%
GPS_sample_compare=GPS_sample.groupby(['Genres categorical'])['Rating'].count().sort_values(ascending=True)
GPS_under_rating=GPS_sample_compare
GPS_under_rating=pd.DataFrame(GPS_Top_rating)
GPS_under_rating
# Out:
#                     Rating
# Genres categorical
# Tools                   27
# Entertainment           21
# Medical                 15
# Finance                 14
# Education               14
# Sports                  13
# Lifestyle               13
# Action                  13
# Simulation              11
# Photography             11

# %%
GPS_Top_rating.reset_index(level=0,inplace=True)
GPS_Top_rating
# Out:
#   Genres categorical  Rating
# 0              Tools      27
# 1      Entertainment      21
# 2            Medical      15
# 3            Finance      14
# 4          Education      14
# 5             Sports      13
# 6          Lifestyle      13
# 7             Action      13
# 8         Simulation      11
# 9        Photography      11

# %%
plt.figure(figsize=(4,5))
ax=plt.axes()
plt.barh(GPS_Top_rating['Genres categorical'],GPS_Top_rating.Rating,label='Top Rated Category',color='r')
# Out:
# <BarContainer object of 10 artists>

# %%
GPS_sample_Reviews=GPS_sample.groupby(['Genres categorical'])['Reviews'].count()
GPS_sample_Reviews=pd.DataFrame(GPS_sample_Reviews)
GPS_sample_Reviews
# Out:
#                                Reviews
# Genres categorical
# Action                              13
# Adventure                            5
# Adventure;Action & Adventure         1
# Arcade                               6
# Arcade;Action & Adventure            1
# Art & Design                         3
# Auto & Vehicles                      2
# Beauty                               1
# Board                                2
# Board;Brain Games                    1
# Books & Reference                    7
# Business                             7
# Casino                               2
# Casual                               6
# Casual;Action & Adventure            2
# Casual;Brain Games                   1
# Casual;Creativity                    1
# Casual;Pretend Play                  1
# Comics                               3
# Communication                       10
# Dating                               8
# Education                           14
# ...

# %%
sns.catplot(x='Reviews',y='Rating',hue='genretargeted',col='Type of access',kind='point',data=GPS_sample.head(10))
plt.show()

# %%
sns.catplot(x='Reviews',y='Rating',hue='Genres categorical',col='Type of access',kind='point',data=GPS_sample.head(10))
plt.show()

# %% [markdown]
# ##### This gave a clear idea that free apps were installed too much compared to paid ones and also rating and reviews are given more to free Apps

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Installs',data=GPS_sample.head(30),palette='tab10')
plt.show()

# %%
GPS_sample_head=GPS_sample.sample(30)
GPS_sample_head.groupby('App')[['Rating','Price']].sum().plot.bar(color=['green','blue'],figsize=(8,5))
plt.ylabel('Type of access')
plt.show()

# %%
GPS_sample_free_apps=GPS_sample[GPS_sample['Type of access']=='Free']
GPS_sample_free_apps
# Out:
#                                  App  Rating  Reviews   Installs  Price  \
# 6800               CT Abdomen Pelvis     4.0       36      10000    0.0
# 2413   World Travel Guide by Triposo     4.4     6012     500000    0.0
# 5330               Real DJ Simulator     4.0    68664   10000000    0.0
# 3247  EBookDroid - PDF & DJVU Reader     4.5    75951    5000000    0.0
# 5318  Real Casino:Slot,Keno,BJ,Poker     4.1      341      50000    0.0
# ...                              ...     ...      ...        ...    ...
# 5074             Free GPS Navigation     4.2   618562   50000000    0.0
# 4085               AE Fishing Hunter     4.4       14       1000    0.0
# 3455     M Launcher -Marshmallow 6.0     4.4    37234    1000000    0.0
# 2269                Photo Editor Pro     4.3  1871416  100000000    0.0
# 903     Mint: Budget, Bills, Finance     4.3   129304    5000000    0.0
#
#      genretargeted  Genres  Current Ver  Android Ver            Category   \
# ...

# %%
GPS_sample_paid_apps=GPS_sample[GPS_sample['Type of access']=='Paid']
GPS_sample_paid_apps
# Out:
#                                                   App  Rating  Reviews  \
# 4650                          Five Nights at Freddy's     4.6   100805
# 6160        TI-84 CE Graphing Calculator Manual TI 84     5.0        1
# 1791                   Critical Care Paramedic Review     4.4       17
# 406                         Moco+ - Chat, Meet People     4.2     1545
# 9365                     Ray Financial Calculator Pro     4.0       67
# 3843                                   X-Plane to GPS     4.2      161
# 4405                           I am Rich Premium Plus     4.6      459
# 3702                   Please Don't Touch Anything 3D     4.2      146
# 5338                                  Phonics Puzzles     3.8        4
# 3877                         Z Origins - (Z The Game)     4.6     4421
# 7937                      Santa's Monster Shootout DX     5.0        4
# 5555                                  Bo's School Day     4.7       10
# ...

# %%
GPS_sample['Current Ver ext'].value_counts()
# Out:
# Varies with device    44
# 1                     11
# 1.1                   10
# 4                      7
# 2                      5
#                       ..
# 1.5.1                  1
# 2.7                    1
# 9.1.4                  1
# 2.19.6                 1
# 1.4.9                  1
# Name: Current Ver ext, Length: 221, dtype: int64
